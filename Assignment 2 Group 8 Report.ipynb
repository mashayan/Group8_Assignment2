# %% [markdown]
# # Assignment 2 - Group 8

# %% [markdown]
# # Question 1

# %% [markdown]
# 1.1 For this assignment we use:
#    * pd.read_csv('price_demand_data.csv') to read the price_demand_data file
#    * pd.read_csv('weather_data.csv') to read the weather_data file
#    * df.head() to see what columns/fields there are in each data files
#    * df.apply (lambda x: x.split()[0]) to get the date dd/mm/yyyy from SETTLEMENTDATE column in the price_demand_data file so we can join it with the weather_data file
#    * df.merge method to join the two above mentioned file
#    * .groupby and .max() methods to aggregate data by date
#    * .fillna and .mean() methods to replace NaT value with mean value
#    * .isnull() to double check that there is no NaT value in the columns used for analysis

# %% [markdown]
# 1.2  We have chosen these methods over other alternatives because:
#
#   *
#   *
#   *

# %%
import pandas as pd

df1 = pd.read_csv('price_demand_data.csv')
df2 = pd.read_csv('weather_data.csv')

# %%
df1.head()
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0   VIC1  1/01/2021 0:30      4179.21           LOW
# 1   VIC1  1/01/2021 1:00      4047.76           LOW
# 2   VIC1  1/01/2021 1:30      3934.70           LOW
# 3   VIC1  1/01/2021 2:00      3766.45           LOW
# 4   VIC1  1/01/2021 2:30      3590.37           LOW

# %%
df2.head()
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# 2                             WSW                               33.0
# 3                             SSE                               41.0
# 4                             SSE                               35.0
#
#   Time of maximum wind gust  9am Temperature (°C)  ...  \
# 0                     13:14                  19.2  ...
# 1                      8:22                  23.3  ...
# 2                     17:55                  18.3  ...
# 3                     16:03                  16.2  ...
# 4                     11:02                  17.2  ...
#
#    9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 0                         6                   N                     2
# 1                         7                 NNW                    17
# 2                         8                 WSW                     4
# 3                         8                 SSE                    11
# 4                         8                 SSE                    13
#
#   9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                 1018.8                  28.1                         43
# 1                 1013.3                  28.7                         38
# 2                 1007.7                  23.5                         59
# 3                 1010.0                  18.2                         82
# 4                 1012.5                  18.2                         82
#
#    3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 0                       5.0                   E                    13
# 1                       7.0                  SW                     4
# 2                       4.0                 SSW                     2
# 3                       8.0                 SSW                    17
# 4                       8.0                 SSE                    19
#
#   3pm MSL pressure (hPa)
# 0                 1015.3
# 1                 1008.5
# 2                 1005.2
# 3                 1011.0
# 4                 1013.3
#
# [5 rows x 21 columns]

# %%
# Get the dd/mm/yyyy field from SETTLEMENTDATE so we can join it with the weather

df1['Date'] = df1['SETTLEMENTDATE'].apply(lambda x: x.split()[0])
df1.head()
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY       Date
# 0   VIC1  1/01/2021 0:30      4179.21           LOW  1/01/2021
# 1   VIC1  1/01/2021 1:00      4047.76           LOW  1/01/2021
# 2   VIC1  1/01/2021 1:30      3934.70           LOW  1/01/2021
# 3   VIC1  1/01/2021 2:00      3766.45           LOW  1/01/2021
# 4   VIC1  1/01/2021 2:30      3590.37           LOW  1/01/2021

# %%
# Merge the two datasets based on the date

data = df1.merge(df2, left_on='Date', right_on='Date')
data.head()
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY       Date  \
# 0   VIC1  1/01/2021 0:30      4179.21           LOW  1/01/2021
# 1   VIC1  1/01/2021 1:00      4047.76           LOW  1/01/2021
# 2   VIC1  1/01/2021 1:30      3934.70           LOW  1/01/2021
# 3   VIC1  1/01/2021 2:00      3766.45           LOW  1/01/2021
# 4   VIC1  1/01/2021 2:30      3590.37           LOW  1/01/2021
#
#    Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                      15.6                      29.9            0.0
# 1                      15.6                      29.9            0.0
# 2                      15.6                      29.9            0.0
# 3                      15.6                      29.9            0.0
# 4                      15.6                      29.9            0.0
#
#    Evaporation (mm)  Sunshine (hours)  ... 9am cloud amount (oktas)  \
# 0               2.8               9.3  ...                        6
# 1               2.8               9.3  ...                        6
# 2               2.8               9.3  ...                        6
# 3               2.8               9.3  ...                        6
# 4               2.8               9.3  ...                        6
#
#    9am wind direction 9am wind speed (km/h)  9am MSL pressure (hPa)  \
# 0                   N                     2                  1018.8
# 1                   N                     2                  1018.8
# 2                   N                     2                  1018.8
# 3                   N                     2                  1018.8
# 4                   N                     2                  1018.8
#
#    3pm Temperature (°C)  3pm relative humidity (%) 3pm cloud amount (oktas)  \
# 0                  28.1                         43                      5.0
# 1                  28.1                         43                      5.0
# 2                  28.1                         43                      5.0
# 3                  28.1                         43                      5.0
# 4                  28.1                         43                      5.0
#
#   3pm wind direction  3pm wind speed (km/h)  3pm MSL pressure (hPa)
# 0                  E                     13                  1015.3
# 1                  E                     13                  1015.3
# 2                  E                     13                  1015.3
# 3                  E                     13                  1015.3
# 4                  E                     13                  1015.3
#
# [5 rows x 25 columns]

# %%
# Aggreate data by date to have a single entry for each day
# Use max() method to select the maximum value for each day

aggregate_data = data.groupby('Date').max()
aggregate_data
# Out:
#           REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY  \
# Date
# 1/01/2021   VIC1  1/01/2021 9:30      5019.64           LOW
# 1/02/2021   VIC1  1/02/2021 9:30      5228.29        MEDIUM
# 1/03/2021   VIC1  1/03/2021 9:30      5225.37           LOW
# 1/04/2021   VIC1  1/04/2021 9:30      5807.02        MEDIUM
# 1/05/2021   VIC1  1/05/2021 9:30      5261.09        MEDIUM
# ...          ...             ...          ...           ...
# 9/04/2021   VIC1  9/04/2021 9:30      5688.63        MEDIUM
# 9/05/2021   VIC1  9/05/2021 9:30      5222.89        MEDIUM
# 9/06/2021   VIC1  9/06/2021 9:30      7224.91        MEDIUM
# 9/07/2021   VIC1  9/07/2021 9:30      7536.11          HIGH
# 9/08/2021   VIC1  9/08/2021 9:30      6675.69        MEDIUM
#
#            Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 1/01/2021                      15.6                      29.9            0.0
# 1/02/2021                      13.4                      20.3            0.0
# 1/03/2021                      13.8                      21.7            0.0
# 1/04/2021                      12.4                      29.9            0.0
# 1/05/2021                      11.2                      24.6            0.0
# ...                             ...                       ...            ...
# 9/04/2021                      13.8                      17.3            6.2
# 9/05/2021                      11.0                      20.5            0.4
# 9/06/2021                       7.8                      14.7            4.0
# 9/07/2021                       2.0                      12.0            NaN
# 9/08/2021                       7.1                      16.4            0.0
#
#            Evaporation (mm)  Sunshine (hours) Direction of maximum wind gust   \
# Date
# 1/01/2021               2.8               9.3                             NNE
# 1/02/2021               7.4               1.6                               S
# 1/03/2021               6.4               6.3                               S
# 1/04/2021               4.4              10.8                             NNW
# 1/05/2021               5.4               7.1                               N
# ...                     ...               ...                             ...
# 9/04/2021               6.4               7.9                               S
# 9/05/2021               0.0               7.1                              NW
# 9/06/2021               1.6               0.5                               S
# 9/07/2021               1.0               9.0                             NNE
# 9/08/2021               2.8               2.7                               N
#
#            ...  9am cloud amount (oktas) 9am wind direction  \
# Date       ...
# 1/01/2021  ...                         6                  N
# 1/02/2021  ...                         7                  N
# 1/03/2021  ...                         6                WSW
# 1/04/2021  ...                         1                 NE
# 1/05/2021  ...                         3                NNE
# ...        ...                       ...                ...
# 9/04/2021  ...                         5                  W
# 9/05/2021  ...                         6
# 9/06/2021  ...                         7                SSW
# 9/07/2021  ...                         4                 NE
# 9/08/2021  ...                         7                NNE
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 1/01/2021                      2                  1018.8
# 1/02/2021                      7                  1012.8
# 1/03/2021                      6                  1012.3
# 1/04/2021                      9                  1024.3
# 1/05/2021                      9                  1027.3
# ...                          ...                     ...
# 9/04/2021                     13                  1010.0
# 9/05/2021                   Calm                  1018.4
# 9/06/2021                      4                  1010.7
# 9/07/2021                      4                  1017.9
# 9/08/2021                      9                  1028.1
#
#            3pm Temperature (°C) 3pm relative humidity (%)  \
# Date
# 1/01/2021                  28.1                        43
# 1/02/2021                  19.4                        69
# 1/03/2021                  19.7                        67
# 1/04/2021                  28.7                        30
# 1/05/2021                  24.2                        35
# ...                         ...                       ...
# 9/04/2021                  15.7                        62
# 9/05/2021                  19.5                        45
# 9/06/2021                  12.3                        86
# 9/07/2021                  11.0                        67
# 9/08/2021                  15.1                        60
#
#           3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# Date
# 1/01/2021                      5.0                   E                     13
# 1/02/2021                      7.0                   S                     13
# 1/03/2021                      6.0                   S                     15
# 1/04/2021                      3.0                  SE                      7
# 1/05/2021                      7.0                   N                     17
# ...                            ...                 ...                    ...
# 9/04/2021                      6.0                   S                     17
# 9/05/2021                      3.0                 WNW                      6
# 9/06/2021                      8.0                   S                     20
# 9/07/2021                      2.0                 SSW                      7
# 9/08/2021                      6.0                 NNW                     19
#
#            3pm MSL pressure (hPa)
# Date
# 1/01/2021                  1015.3
# 1/02/2021                  1011.9
# 1/03/2021                  1012.2
# 1/04/2021                  1021.6
# 1/05/2021                  1024.4
# ...                           ...
# 9/04/2021                  1009.6
# 9/05/2021                  1014.9
# 9/06/2021                  1008.8
# 9/07/2021                  1015.7
# 9/08/2021                  1023.3
#
# [243 rows x 24 columns]

# %%
# Replace NaT value with mean value

cleaned_aggregate_data = aggregate_data.fillna(aggregate_data.mean())
cleaned_aggregate_data
# Out:
#           REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY  \
# Date
# 1/01/2021   VIC1  1/01/2021 9:30      5019.64           LOW
# 1/02/2021   VIC1  1/02/2021 9:30      5228.29        MEDIUM
# 1/03/2021   VIC1  1/03/2021 9:30      5225.37           LOW
# 1/04/2021   VIC1  1/04/2021 9:30      5807.02        MEDIUM
# 1/05/2021   VIC1  1/05/2021 9:30      5261.09        MEDIUM
# ...          ...             ...          ...           ...
# 9/04/2021   VIC1  9/04/2021 9:30      5688.63        MEDIUM
# 9/05/2021   VIC1  9/05/2021 9:30      5222.89        MEDIUM
# 9/06/2021   VIC1  9/06/2021 9:30      7224.91        MEDIUM
# 9/07/2021   VIC1  9/07/2021 9:30      7536.11          HIGH
# 9/08/2021   VIC1  9/08/2021 9:30      6675.69        MEDIUM
#
#            Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# Date
# 1/01/2021                      15.6                      29.9       0.000000
# 1/02/2021                      13.4                      20.3       0.000000
# 1/03/2021                      13.8                      21.7       0.000000
# 1/04/2021                      12.4                      29.9       0.000000
# 1/05/2021                      11.2                      24.6       0.000000
# ...                             ...                       ...            ...
# 9/04/2021                      13.8                      17.3       6.200000
# 9/05/2021                      11.0                      20.5       0.400000
# 9/06/2021                       7.8                      14.7       4.000000
# 9/07/2021                       2.0                      12.0       1.576763
# 9/08/2021                       7.1                      16.4       0.000000
#
#            Evaporation (mm)  Sunshine (hours) Direction of maximum wind gust   \
# Date
# 1/01/2021               2.8               9.3                             NNE
# 1/02/2021               7.4               1.6                               S
# 1/03/2021               6.4               6.3                               S
# 1/04/2021               4.4              10.8                             NNW
# 1/05/2021               5.4               7.1                               N
# ...                     ...               ...                             ...
# 9/04/2021               6.4               7.9                               S
# 9/05/2021               0.0               7.1                              NW
# 9/06/2021               1.6               0.5                               S
# 9/07/2021               1.0               9.0                             NNE
# 9/08/2021               2.8               2.7                               N
#
#            ...  9am cloud amount (oktas) 9am wind direction  \
# Date       ...
# 1/01/2021  ...                         6                  N
# 1/02/2021  ...                         7                  N
# 1/03/2021  ...                         6                WSW
# 1/04/2021  ...                         1                 NE
# 1/05/2021  ...                         3                NNE
# ...        ...                       ...                ...
# 9/04/2021  ...                         5                  W
# 9/05/2021  ...                         6
# 9/06/2021  ...                         7                SSW
# 9/07/2021  ...                         4                 NE
# 9/08/2021  ...                         7                NNE
#
#            9am wind speed (km/h)  9am MSL pressure (hPa)  \
# Date
# 1/01/2021                      2                  1018.8
# 1/02/2021                      7                  1012.8
# 1/03/2021                      6                  1012.3
# 1/04/2021                      9                  1024.3
# 1/05/2021                      9                  1027.3
# ...                          ...                     ...
# 9/04/2021                     13                  1010.0
# 9/05/2021                   Calm                  1018.4
# 9/06/2021                      4                  1010.7
# 9/07/2021                      4                  1017.9
# 9/08/2021                      9                  1028.1
#
#            3pm Temperature (°C) 3pm relative humidity (%)  \
# Date
# 1/01/2021                  28.1                        43
# 1/02/2021                  19.4                        69
# 1/03/2021                  19.7                        67
# 1/04/2021                  28.7                        30
# 1/05/2021                  24.2                        35
# ...                         ...                       ...
# 9/04/2021                  15.7                        62
# 9/05/2021                  19.5                        45
# 9/06/2021                  12.3                        86
# 9/07/2021                  11.0                        67
# 9/08/2021                  15.1                        60
#
#           3pm cloud amount (oktas)  3pm wind direction  3pm wind speed (km/h)  \
# Date
# 1/01/2021                      5.0                   E                     13
# 1/02/2021                      7.0                   S                     13
# 1/03/2021                      6.0                   S                     15
# 1/04/2021                      3.0                  SE                      7
# 1/05/2021                      7.0                   N                     17
# ...                            ...                 ...                    ...
# 9/04/2021                      6.0                   S                     17
# 9/05/2021                      3.0                 WNW                      6
# 9/06/2021                      8.0                   S                     20
# 9/07/2021                      2.0                 SSW                      7
# 9/08/2021                      6.0                 NNW                     19
#
#            3pm MSL pressure (hPa)
# Date
# 1/01/2021                  1015.3
# 1/02/2021                  1011.9
# 1/03/2021                  1012.2
# 1/04/2021                  1021.6
# 1/05/2021                  1024.4
# ...                           ...
# 9/04/2021                  1009.6
# 9/05/2021                  1014.9
# 9/06/2021                  1008.8
# 9/07/2021                  1015.7
# 9/08/2021                  1023.3
#
# [243 rows x 24 columns]

# %%
# Check te columns again to make sure there is no NaT value left in the columns used for the analysis 

cleaned_aggregate_data.isnull().sum()
# Out:
# REGION                               0
# SETTLEMENTDATE                       0
# TOTALDEMAND                          0
# PRICECATEGORY                        0
# Minimum temperature (°C)             0
# Maximum temperature (°C)             0
# Rainfall (mm)                        0
# Evaporation (mm)                     0
# Sunshine (hours)                     0
# Direction of maximum wind gust       3
# Speed of maximum wind gust (km/h)    0
# Time of maximum wind gust            3
# 9am Temperature (°C)                 0
# 9am relative humidity (%)            0
# 9am cloud amount (oktas)             0
# 9am wind direction                   1
# 9am wind speed (km/h)                1
# 9am MSL pressure (hPa)               0
# 3pm Temperature (°C)                 0
# 3pm relative humidity (%)            0
# 3pm cloud amount (oktas)             0
# 3pm wind direction                   0
# 3pm wind speed (km/h)                0
# 3pm MSL pressure (hPa)               0
# dtype: int64

# %% [markdown]
# # Question 2

# %% [markdown]
# How have you gone about building your models and how do your models work?

# %% [markdown]
# # Question 3

# %% [markdown]
# How effective are your models? How have you evaluated this?

# %% [markdown]
# # Question 4

# %% [markdown]
# What insights can you draw from your analysis? For example, which input variables
# are most valuable for predicting energy usage/price?

# %% [markdown]
# # Question 5

# %% [markdown]
# Why are your results significant and valuable?

# %% [markdown]
# # Question 6

# %% [markdown]
# What are the limitations of your results and how can the project be improved for future?
